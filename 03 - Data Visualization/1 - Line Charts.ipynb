# %% [markdown]
# ![Screen%20Shot%202021-07-22%20at%2021.45.45.png](attachment:Screen%20Shot%202021-07-22%20at%2021.45.45.png)

# %% [markdown]
# ### Review the data

# %%
museum_filepath = "../input/museum_visitors.csv"
museum_data = pd.read_csv(museum_filepath, index_col='Date', parse_dates=True)

# %%
museum_data.tail()

# %% [markdown]
# ![Screen%20Shot%202021-07-22%20at%2021.46.45.png](attachment:Screen%20Shot%202021-07-22%20at%2021.46.45.png)

# %% [markdown]
# ### Visualize the data

# %%
sns.lineplot(data=museum_data)

# %% [markdown]
# ![Screen%20Shot%202021-07-22%20at%2021.48.03.png](attachment:Screen%20Shot%202021-07-22%20at%2021.48.03.png)

# %%
sns.lineplot(data=museum_data['Avila Adobe'])

# %% [markdown]
# ![Screen%20Shot%202021-07-22%20at%2021.48.30.png](attachment:Screen%20Shot%202021-07-22%20at%2021.48.30.png)
