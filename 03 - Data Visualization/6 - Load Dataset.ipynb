# %% [markdown]
# ![Screen%20Shot%202021-07-26%20at%2008.46.20.png](attachment:Screen%20Shot%202021-07-26%20at%2008.46.20.png)

# %% [markdown]
# ### getting the filepath

# %% [markdown]
# ![Screen%20Shot%202021-07-26%20at%2008.47.10.png](attachment:Screen%20Shot%202021-07-26%20at%2008.47.10.png)

# %%
my_data = pd.read_csv(my_filepath)
my_data.head()
