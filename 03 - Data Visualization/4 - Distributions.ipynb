# %% [markdown]
# ![Screen%20Shot%202021-07-25%20at%2011.34.38.png](attachment:Screen%20Shot%202021-07-25%20at%2011.34.38.png)

# %%
cancer_b_filepath = "../input/cancer_b.csv"
cancer_m_filepath = "../input/cancer_m.csv"
cancer_b_data = pd.read_csv(cancer_b_filepath, index_col='Id')
cancer_m_data = pd.read_csv(cancer_m_filepath, index_col='Id')

cancer_b_data.head()

# %% [markdown]
# ![Screen%20Shot%202021-07-25%20at%2011.36.05.png](attachment:Screen%20Shot%202021-07-25%20at%2011.36.05.png)

# %%
sns.distplot(cancer_b_data['Area (mean)'])
sns.distplot(cancer_m_data['Area (mean)'])

# %% [markdown]
# ![Screen%20Shot%202021-07-25%20at%2011.36.39.png](attachment:Screen%20Shot%202021-07-25%20at%2011.36.39.png)

# %%
sns.kdeplot(cancer_b_data['Radius (worst)'], shade=True)
sns.kdeplot(cancer_m_data['Radius (worst)'], shade=True)

# %% [markdown]
# ![Screen%20Shot%202021-07-25%20at%2011.37.03.png](attachment:Screen%20Shot%202021-07-25%20at%2011.37.03.png)
