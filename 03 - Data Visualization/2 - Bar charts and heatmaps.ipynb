# %% [markdown]
# ![Screen%20Shot%202021-07-23%20at%2011.13.25.png](attachment:Screen%20Shot%202021-07-23%20at%2011.13.25.png)

# %%
ign_filepath = "../input/ign_scores.csv"
ign_data = pd.read_csv(ign_filepath, index_col='Platform')
print(ign_data)

# %% [markdown]
# ![Screen%20Shot%202021-07-23%20at%2011.14.09.png](attachment:Screen%20Shot%202021-07-23%20at%2011.14.09.png)

# %%
high_score = 7.759930
worst_genre = 'Simulation'

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x=ign_data.index, y=ign_data['Racing'])

# %% [markdown]
# ![Screen%20Shot%202021-07-23%20at%2011.14.53.png](attachment:Screen%20Shot%202021-07-23%20at%2011.14.53.png)

# %%
plt.figure(figsize=(14, 7))
sns.heatmap(data=ign_data, annot=True)

# %% [markdown]
# ![Screen%20Shot%202021-07-23%20at%2011.15.20.png](attachment:Screen%20Shot%202021-07-23%20at%2011.15.20.png)
