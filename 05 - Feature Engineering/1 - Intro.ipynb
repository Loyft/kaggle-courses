# %% [markdown]
# ### Goals of Feature Engineering

# %% [markdown]
# - improve a model's predictive performance
# - reduce computational or data needs
# - improve interpretability of the results

# %% [markdown]
# ![Screen%20Shot%202021-07-30%20at%2011.23.18.png](attachment:Screen%20Shot%202021-07-30%20at%2011.23.18.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-30%20at%2011.23.36.png](attachment:Screen%20Shot%202021-07-30%20at%2011.23.36.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-30%20at%2011.23.59.png](attachment:Screen%20Shot%202021-07-30%20at%2011.23.59.png)
